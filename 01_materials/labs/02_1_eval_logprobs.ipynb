# %% [markdown]
# # Evaluating Model Outputs
#
# This notebook demonstrates how to obtain and use logprobs from the Completions API. Many of these examples are adapted from the ["Using logprobs" from the OpenAI Cookbook](https://cookbook.openai.com/examples/using_logprobs#0-imports-and-utils).
#
#
# ## Logprobs and Classification
#
# The first thing to notice is that the Responses and Completions APIs can return logprobs. Not every model provider will return logprobs. Two key parameters to obtain logprobs are:
#
# - `logprobs`: whether to retunr the log rpobabilities of the output tokens. If true, returns the logprobs of each output token returned in the content message.
# - `top_logprobs`: An integer between 0 and 20 specifying the number of most likely tokens to return at each token position, each with an associated log probability. This parameter requires `logprobs = True`.
#
# Log probabilities or logprobs are $log(p)$ where $p$ is the probability of a token occurring at a specific position based on the previous tokens in the context.

# %%
# %load_ext dotenv
# %dotenv ../../05_src/.env
# %dotenv ../../05_src/.secrets
import sys
sys.path.append('../../05_src/')

# %%
from utils.clients import get_client
import numpy as np
import os
client = get_client()
MODEL = os.getenv('MODEL', 'gpt-4o-mini')

# %% [markdown]
# First, we establish a simple interface that we can use for our experiments.

# %%
def get_completion(
    input: list[dict[str, str]],
    model: str = "gpt-4o-mini",
    max_tokens=500,
    temperature=0,
    tools=None,
    logprobs=None,  # whether to return log probabilities of the output tokens or not. If true, returns the log probabilities of each output token returned in the content of message..
    top_logprobs=None,
) -> str:
    params = {
        "model": model,
        "input": input,
        "max_output_tokens": max_tokens,
        "temperature": temperature,
        "tools": tools,
        "include": ["message.output_text.logprobs"] if logprobs else [],
        "top_logprobs": top_logprobs,
    }
    if tools:
        params["tools"] = tools

    completion = client.responses.create(**params)
    return completion

# %%
headlines = [
    # Sports vs. Business
    "Caitlin Clark Signs Record $28M Nike Shoe Deal",
    "Formula 1 Teams Threaten Strike Over Revenue Sharing Dispute",
    # Sports vs. Politics
    "NBA Players Boycott Games to Protest Police Brutality",
    "IOC Bans Russian Athletes from Paris Olympics Over Ukraine War",
    # Entertainment vs. Politics
    "Jon Stewart Returns to The Daily Show Ahead of Election Season",
    "Celebrities Flood Campaign Trail as Election Nears",
    # Crime vs. Business
    "FTX Founder Sam Bankman-Fried Sentenced to 25 Years in Fraud Case",
    "Pharmacy Chain Sued for Knowingly Fueling Opioid Crisis",
    # Art vs. Entertainment
    "Taylor Swift's 'Tortured Poets Department' Wins Album of the Year Grammy",
    "Kanye West Announces Surprise Art Exhibition in Venice",
    # Crime vs. Politics
    "Senator's Chief of Staff Arrested on Bribery Charges",
    # Sports / Crime / Entertainment (three-way split)
    "O.J. Simpson, NFL Star Acquitted of Murder, Dies at 76",
]

# %%
CLASSIFICATION_PROMPT = """You will be given a headline of a news article.
Classify the article into one of the following categories: Business,  Politics, Crime, Sports, Art, and Entertainment.
Return only the name of the category, and nothing else.
MAKE SURE your output is one of the six categories stated.
Article headline: {headline}"""

# %% [markdown]
# We can use the interface to obtain the classification that we requested. However, it does not show the logprobs of the different top options.

# %%
for headline in headlines:
    print(f"\nHeadline: {headline}")
    response = get_completion(
        [{"role": "user", "content": CLASSIFICATION_PROMPT.format(headline=headline)}],
        model=MODEL,
    )
    print(f"Category: {response.output_text}\n")
# Out:
# Headline: Caitlin Clark Signs Record $28M Nike Shoe Deal
# Category: Sports
#
#
# Headline: Formula 1 Teams Threaten Strike Over Revenue Sharing Dispute
# Category: Sports
#
#
# Headline: NBA Players Boycott Games to Protest Police Brutality
# Category: Sports
#
#
# Headline: IOC Bans Russian Athletes from Paris Olympics Over Ukraine War
# Category: Politics
#
#
# Headline: Jon Stewart Returns to The Daily Show Ahead of Election Season
# Category: Entertainment
#
#
# Headline: Celebrities Flood Campaign Trail as Election Nears
# Category: Politics
#
#
# Headline: FTX Founder Sam Bankman-Fried Sentenced to 25 Years in Fraud Case
# Category: Crime
#
#
# Headline: Pharmacy Chain Sued for Knowingly Fueling Opioid Crisis
# Category: Crime
#
#
# Headline: Taylor Swift's 'Tortured Poets Department' Wins Album of the Year Grammy
# Category: Entertainment
#
#
# Headline: Kanye West Announces Surprise Art Exhibition in Venice
# Category: Art
#
#
# Headline: Senator's Chief of Staff Arrested on Bribery Charges
# Category: Politics
#
#
# Headline: O.J. Simpson, NFL Star Acquitted of Murder, Dies at 76
# Category: Entertainment

# %% [markdown]
# Showing the top two options with their log and linear probabilities.

# %%
for headline in headlines:
    print(f"\nHeadline: {headline}")
    API_RESPONSE = get_completion(
        [{"role": "user", "content": CLASSIFICATION_PROMPT.format(headline=headline)}],
        model="gpt-4o-mini",
        logprobs=True,
        top_logprobs=2,
    )
    top_n_logprobs = API_RESPONSE.output[0].content[0].logprobs[0].top_logprobs
    output_content = ""
    for i, logprob in enumerate(top_n_logprobs, start=1):
        output_content += (
            f"Output token {i}: {logprob.token}, "
            f"logprobs: {logprob.logprob}, "
            f"linear probability: {np.round(np.exp(logprob.logprob)*100,2)}%\n"
        )
    print(output_content)
    print("\n")
# Out:
# Headline: Caitlin Clark Signs Record $28M Nike Shoe Deal
# Output token 1: Sports, logprobs: -0.12709, linear probability: 88.07%
# Output token 2: Business, logprobs: -2.12709, linear probability: 11.92%
#
#
#
#
# Headline: Formula 1 Teams Threaten Strike Over Revenue Sharing Dispute
# Output token 1: Sports, logprobs: -0.000576, linear probability: 99.94%
# Output token 2: Politics, logprobs: -7.750576, linear probability: 0.04%
#
#
#
#
# Headline: NBA Players Boycott Games to Protest Police Brutality
# Output token 1: Sports, logprobs: -0.000914, linear probability: 99.91%
# Output token 2: Politics, logprobs: -7.000914, linear probability: 0.09%
#
#
#
#
# Headline: IOC Bans Russian Athletes from Paris Olympics Over Ukraine War
# Output token 1: Politics, logprobs: -0.25193, linear probability: 77.73%
# Output token 2: Sports, logprobs: -1.50193, linear probability: 22.27%
#
#
#
#
# Headline: Jon Stewart Returns to The Daily Show Ahead of Election Season
# Output token 1: Entertainment, logprobs: -0.000127, linear probability: 99.99%
# Output token 2: Art, logprobs: -9.000127, linear probability: 0.01%
#
#
#
#
# Headline: Celebrities Flood Campaign Trail as Election Nears
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\httpcore\_sync\connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\httpcore\_sync\connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\httpcore\_backends\sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File ~\AppData\Roaming\uv\python\cpython-3.11-windows-x86_64-none\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\openai\_base_client.py:1037, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1036 try:
# -> 1037     response = self._send_request(
#    1038         request,
#    1039         stream=stream or self._should_stream_response_body(request=request),
#    1040         **kwargs,
#    1041     )
#    1042 except httpx.TimeoutException as err:
#
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\openai\_client.py:440, in OpenAI._send_request(self, request, stream, **kwargs)
#     432 @override
#     433 def _send_request(
#     434     self,
#    (...)    438     **kwargs: Unpack[HttpxSendArgs],
#     439 ) -> httpx.Response:
# --> 440     return self._send_with_auth_retry(request, stream=stream, **kwargs)
#
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\openai\_client.py:418, in OpenAI._send_with_auth_retry(self, request, stream, retried, **kwargs)
#     416         used_workload_identity_auth = True
# --> 418 response = super()._send_request(request, stream=stream, **kwargs)
#     419 if (
#     420     response.status_code == 401
#     421     and self._workload_identity_auth is not None
#     422     and used_workload_identity_auth
#     423     and not retried
#     424 ):
#
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\openai\_base_client.py:964, in SyncAPIClient._send_request(self, request, stream, **kwargs)
#     957 def _send_request(
#     958     self,
#     959     request: httpx.Request,
#    (...)    962     **kwargs: Unpack[HttpxSendArgs],
#     963 ) -> httpx.Response:
# --> 964     return self._client.send(request, stream=stream, **kwargs)
#
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\httpx\_transports\default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File ~\AppData\Roaming\uv\python\cpython-3.11-windows-x86_64-none\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\httpx\_transports\default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[10], line 3
#       1 for headline in headlines:
#       2     print(f"\nHeadline: {headline}")
# ----> 3     API_RESPONSE = get_completion(
#       4         [{"role": "user", "content": CLASSIFICATION_PROMPT.format(headline=headline)}],
#       5         model="gpt-4o-mini",
#       6         logprobs=True,
#
# Cell In[3], line 22, in get_completion(input, model, max_tokens, temperature, tools, logprobs, top_logprobs)
#      18     }
#      19     if tools:
#      20         params["tools"] = tools
#      21
# ---> 22     completion = client.responses.create(**params)
#      23     return completion
#
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\openai\resources\responses\responses.py:954, in Responses.create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, moderation, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     914 def create(
#     915     self,
#     916     *,
#    (...)    952     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     953 ) -> Response | Stream[ResponseStreamEvent]:
# --> 954     return self._post(
#     955         "/responses",
#     956         body=maybe_transform(
#     957             {
#     958                 "background": background,
#     959                 "context_management": context_management,
#     960                 "conversation": conversation,
#     961                 "include": include,
#     962                 "input": input,
#     963                 "instructions": instructions,
#     964                 "max_output_tokens": max_output_tokens,
#     965                 "max_tool_calls": max_tool_calls,
#     966                 "metadata": metadata,
#     967                 "model": model,
#     968                 "moderation": moderation,
#     969                 "parallel_tool_calls": parallel_tool_calls,
#     970                 "previous_response_id": previous_response_id,
#     971                 "prompt": prompt,
#     972                 "prompt_cache_key": prompt_cache_key,
#     973                 "prompt_cache_retention": prompt_cache_retention,
#     974                 "reasoning": reasoning,
#     975                 "safety_identifier": safety_identifier,
#     976                 "service_tier": service_tier,
#     977                 "store": store,
#     978                 "stream": stream,
#     979                 "stream_options": stream_options,
#     980                 "temperature": temperature,
#     981                 "text": text,
#     982                 "tool_choice": tool_choice,
#     983                 "tools": tools,
#     984                 "top_logprobs": top_logprobs,
#     985                 "top_p": top_p,
#     986                 "truncation": truncation,
#     987                 "user": user,
#     988             },
#     989             response_create_params.ResponseCreateParamsStreaming
#     990             if stream
#     991             else response_create_params.ResponseCreateParamsNonStreaming,
#     992         ),
#     993         options=make_request_options(
#     994             extra_headers=extra_headers,
#     995             extra_query=extra_query,
#     996             extra_body=extra_body,
#     997             timeout=timeout,
#     998             security={"bearer_auth": True},
#     999         ),
#    1000         cast_to=Response,
#    1001         stream=stream or False,
#    1002         stream_cls=Stream[ResponseStreamEvent],
#    1003     )
#
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\steph\Desktop\DSI\deploying-ai\deploying-ai-env\Lib\site-packages\openai\_base_client.py:1072, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1069         continue
#    1071     log.debug("Raising connection error")
# -> 1072     raise APIConnectionError(request=request) from err
#    1074 log.debug(
#    1075     'HTTP Response: %s %s "%i %s" %s',
#    1076     request.method,
#    (...)   1080     response.headers,
#    1081 )
#    1082 log.debug("request_id: %s", response.headers.get("x-request-id"))
#
# APIConnectionError: Connection error.

# %% [markdown]
# In this classification task, we see the usefulness of logprobs:
# + We can determine the degree to which a model is "sure" about a classification that it has proposed.
# + Based on logprobs, we can set a threshold under which human assistance is needed.
# + Alternatively, we can set the logic of our code to provide several options if the logprobs are within a threshold.
